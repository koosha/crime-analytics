# %%
print(__doc__)

# Author: Ji Yang
# for CMPUT 466 course project
# License: MIT
# Out:
# Automatically created module for IPython interactive environment

# %%
# Preset and import 
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', 100)

# %%
# Read data
neighbor_crimes = pd.read_csv('data/EPS_Neighbourhood_Criminal_Incidents.csv')
print(neighbor_crimes)
# Out:
#        # Incidents Neighbourhood Description (Occurrence)  \
# 0                3                           ABBOTTSFIELD
# 1                5                           ABBOTTSFIELD
# 2                2                           ABBOTTSFIELD
# 3                2                           ABBOTTSFIELD
# 4                6                           ABBOTTSFIELD
# 5                4                           ABBOTTSFIELD
# 6                3                           ABBOTTSFIELD
# 7                4                           ABBOTTSFIELD
# 8                4                           ABBOTTSFIELD
# 9                6                           ABBOTTSFIELD
# 10               3                           ABBOTTSFIELD
# 11               2                           ABBOTTSFIELD
# 12               3                           ABBOTTSFIELD
# 13               1                           ABBOTTSFIELD
# 14               1                           ABBOTTSFIELD
# ...

# %%
# Select X and y
X = neighbor_crimes.ix[:,1:6]
y = neighbor_crimes.ix[:,0:1]
