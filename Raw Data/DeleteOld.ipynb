# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('EPS_Neighbourhood_Criminal_Incidents.csv')

# %%
df_ = pd.DataFrame()

# %%
for i, row in df.iterrows():
    if row['Incident Reported Year'] >2010:
        df_ = df_.append(row)

# %%
df
# Out:
#        # Incidents Neighbourhood Description (Occurrence)  \
# 0                3                           ABBOTTSFIELD
# 1                5                           ABBOTTSFIELD
# 2                2                           ABBOTTSFIELD
# 3                2                           ABBOTTSFIELD
# 4                6                           ABBOTTSFIELD
# 5                4                           ABBOTTSFIELD
# 6                3                           ABBOTTSFIELD
# 7                4                           ABBOTTSFIELD
# 8                4                           ABBOTTSFIELD
# 9                6                           ABBOTTSFIELD
# 10               3                           ABBOTTSFIELD
# 11               2                           ABBOTTSFIELD
# 12               3                           ABBOTTSFIELD
# 13               1                           ABBOTTSFIELD
# 14               1                           ABBOTTSFIELD
# ...

# %%
df_
# Out:
#        # Incidents  Incident Reported Month Incident Reported Quarter  \
# 21055          2.0                      1.0                        Q1
# 21056          3.0                      2.0                        Q1
# 21057          1.0                      3.0                        Q1
# 21058          2.0                      4.0                        Q2
# 21059          4.0                      5.0                        Q2
# 21060          1.0                      6.0                        Q2
# 21061          4.0                      7.0                        Q3
# 21062          6.0                      8.0                        Q3
# 21063          6.0                      9.0                        Q3
# 21064          1.0                     10.0                        Q4
# 21065          2.0                     11.0                        Q4
# 21066          2.0                     12.0                        Q4
# ...

# %%
df_.to_csv('Incident Sorted.csv',index=False)
